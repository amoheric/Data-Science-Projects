# %% [markdown]
# <a href="https://colab.research.google.com/github/amoheric/Data-Science-Projects/blob/main/Data_Manipulation_Week_4_Assignment_4_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Download the dataset and load it as a pandas dataframe and perform the following:

# %%
# Display the columns in the DataFrame
print(df.columns)
# Out:
# Index(['Fast-Food Chains', 'U.S. Systemwide Sales (Millions - U.S Dollars)',
#        'Average Sales per Unit (Thousands - U.S Dollars)', 'Franchised Stores',
#        'Company Stores', '2021 Total Units', 'Total Change in Units from 2020',
#        'Fast-Food Chain', 'Systemwide Sales', 'Average Sales per Unit'],
#       dtype='object')

# %%
import pandas as pd

# Attempting to load the dataset from the file path
file_path = '/content/Fast-Food Chains in USA.csv'
df = pd.read_csv(file_path)

# Display the first few rows to understand the structure
df.head()
# Out:
#   Fast-Food Chains  U.S. Systemwide Sales (Millions - U.S Dollars)  \
# 0           Arby’s                                            4462
# 1   Baskin-Robbins                                             686
# 2        Bojangles                                            1485
# 3      Burger King                                           10033
# 4       Carl’s Jr.                                            1560
#
#    Average Sales per Unit (Thousands - U.S Dollars)  Franchised Stores  \
# 0                                              1309               2293
# 1                                               296               2317
# 2                                              1924                496
# 3                                              1470               7054
# 4                                              1400               1011
#
#    Company Stores  2021 Total Units  Total Change in Units from 2020
# ...

# %% [markdown]
# 1. Using pandas to insert a new record into the dataset with the following details:
#
# Fast-Food Chain: "Subway",
#
# Systemwide Sales: $1000 million,
#
# Average Sales per Unit: $400 thousand,
#
# Franchised Stores: 2000,
#
# Company Stores: 500,
#
# 2021 Total Units: 2500,
#
# Total Change in Units from 2020: 50

# %%
import pandas as pd

# Attempting to load the dataset from the file path
file_path = '/content/Fast-Food Chains in USA.csv'
df = pd.read_csv(file_path)

# Displaying the structure of the dataset
print(df.info())
print("\nFirst few rows of the dataset:")


# Displaying the first few rows to understand the structure
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Fast-Food Chains                                  50 non-null     object
#  1   U.S. Systemwide Sales (Millions - U.S Dollars)    50 non-null     int64
#  2   Average Sales per Unit (Thousands - U.S Dollars)  50 non-null     int64
#  3   Franchised Stores                                 50 non-null     int64
#  4   Company Stores                                    50 non-null     int64
#  5   2021 Total Units                                  50 non-null     int64
#  6   Total Change in Units from 2020                   50 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB
# None
#
# First few rows of the dataset:
#   Fast-Food Chains  U.S. Systemwide Sales (Millions - U.S Dollars)  \
# ...

# %%
#Code here

# Display the columns to identify the correct column name
print("Columns in the dataset:")
print(df.columns)

# Inserting the new record into the dataset
new_record = {
    'Fast-Food Chain': 'Subway',
    'Systemwide Sales': 1000,
    'Average Sales per Unit': 400,
    'Franchised Stores': 2000,
    'Company Stores': 500,
    '2021 Total Units': 2500,
    'Total Change in Units from 2020': 50
}

# Converting the new_record to a DataFrame and concatenate with the existing DataFrame
new_record_df = pd.DataFrame([new_record])
df = pd.concat([df, new_record_df], ignore_index=True)
# Out:
# Columns in the dataset:
# Index(['Fast-Food Chains', 'U.S. Systemwide Sales (Millions - U.S Dollars)',
#        'Average Sales per Unit (Thousands - U.S Dollars)', 'Franchised Stores',
#        'Company Stores', '2021 Total Units',
#        'Total Change in Units from 2020'],
#       dtype='object')

# %% [markdown]
# 2. Update the systemwide sales for the fast food chain with the name "McDonald's" to $40000 million.

# %%
#Code here

df.loc[df['Fast-Food Chain'] == "McDonald's", 'Systemwide Sales'] = 40000

# %%
# Checking if the 'Category' column exists, if not, identify the correct column name
print("Columns in the dataset after inserting new record:")
print(df.columns)
# Out:
# Columns in the dataset after inserting new record:
# Index(['Fast-Food Chains', 'U.S. Systemwide Sales (Millions - U.S Dollars)',
#        'Average Sales per Unit (Thousands - U.S Dollars)', 'Franchised Stores',
#        'Company Stores', '2021 Total Units', 'Total Change in Units from 2020',
#        'Fast-Food Chain', 'Systemwide Sales', 'Average Sales per Unit'],
#       dtype='object')

# %% [markdown]
# 3. Using pandas to calculate the average systemwide sales for each category of fast food chains, grouped by category.

# %%
#Code here

# Assuming the correct column name for systemwide sales is 'Systemwide Sales'
correct_column_name = 'Fast-Food Chains'
avg_sales_by_category = df.groupby(correct_column_name)['Systemwide Sales'].mean()

print("Average systemwide sales by category:")
print(avg_sales_by_category)
# Out:
# Average systemwide sales by category:
# Fast-Food Chains
# Arby’s                                   NaN
# Baskin-Robbins                           NaN
# Bojangles                                NaN
# Burger King                              NaN
# Chick-fil-A                              NaN
# Chipotle                                 NaN
# Culver’s                                 NaN
# Del Taco                                 NaN
# Domino's                                 NaN
# Dunkin'                                  NaN
# El Pollo Loco                            NaN
# Firehouse Subs                           NaN
# Five Guys                                NaN
# Freddy’s Frozen Custard & Steakburgers   NaN
# In-N-Out Burger                          NaN
# Jersey Mike’s                            NaN
# Jimmy John’s                             NaN
# KFC                                      NaN
# Krispy Kreme                             NaN
# Marco’s Pizza                            NaN
# ...

# %% [markdown]
# 4.Using pandas retrieve the top 10 fast food chains with the highest average sales per unit, ordered by average sales per unit in descending order.

# %%
#Code here

top_10_chains_by_avg_sales = df.nlargest(10, 'Average Sales per Unit')[['Fast-Food Chain', 'Average Sales per Unit']]

print("\nTop 10 fast food chains by average sales per unit:")
print(top_10_chains_by_avg_sales)
# Out:
# Top 10 fast food chains by average sales per unit:
#    Fast-Food Chain  Average Sales per Unit
# 50          Subway                   400.0
# 0              NaN                     NaN
# 1              NaN                     NaN
# 2              NaN                     NaN
# 3              NaN                     NaN
# 6              NaN                     NaN
# 7              NaN                     NaN
# 9              NaN                     NaN
# 11             NaN                     NaN
# 12             NaN                     NaN

# %% [markdown]
# 5. Using pandas retrieve the names of all fast food chains that have more franchised stores than company stores.

# %%
#Code here

#fast_food_chains = df[(df['Franchised Stores'] > df['Company Stores'])]['Fast-Food Chain']
chains_more_franchised_than_company = df[df['Franchised Stores'] > df['Company Stores']]['Fast-Food Chain']

print("\nFast food chains with more franchised stores than company stores:")
print(chains_more_franchised_than_company)
# Out:
# Fast food chains with more franchised stores than company stores:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 6        NaN
# 9        NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 32       NaN
# 35       NaN
# 36       NaN
# 39       NaN
# 42       NaN
# 43       NaN
# 44       NaN
# 45       NaN
# 48       NaN
# 49       NaN
# 50    Subway
# Name: Fast-Food Chain, dtype: object

# %% [markdown]
# 6. Using pandas delete all records from the dataset where the total change in units from 2020 is negative.

# %%
#Code here

df = df[df['Total Change in Units from 2020'] >= 0]

print("\nDataset after deleting records with negative change in units from 2020:")
print(df)
# Out:
# Dataset after deleting records with negative change in units from 2020:
#                           Fast-Food Chains  \
# 0                                   Arby’s
# 1                           Baskin-Robbins
# 2                                Bojangles
# 3                              Burger King
# 6                              Chick-fil-A
# 7                                 Chipotle
# 9                                 Culver’s
# 11                                Del Taco
# 12                                Domino's
# 13                                 Dunkin'
# 14                           El Pollo Loco
# 15                          Firehouse Subs
# 16                               Five Guys
# 17  Freddy’s Frozen Custard & Steakburgers
# 19                         In-N-Out Burger
# 21                           Jersey Mike’s
# 22                            Jimmy John’s
# 23                                     KFC
# 24                            Krispy Kreme
# ...

# %% [markdown]
# **Displaying all my concluded data manipulation results**

# %%
# Displaying all the results
print("Average systemwide sales by category:")
print(avg_sales_by_category)


print("\nTop 10 fast food chains by average sales per unit:")
print(top_10_chains_by_avg_sales)



print("\nFast food chains with more franchised stores than company stores:")
print(chains_more_franchised_than_company)



print("\nDataset after deleting records with negative change in units from 2020:")
print(df)
# Out:
# Average systemwide sales by category:
# Fast-Food Chains
# Arby’s                                   NaN
# Baskin-Robbins                           NaN
# Bojangles                                NaN
# Burger King                              NaN
# Carl’s Jr.                               NaN
# Checkers/Rally’s                         NaN
# Chick-fil-A                              NaN
# Chipotle                                 NaN
# Church’s Chicken                         NaN
# Culver’s                                 NaN
# Dairy Queen                              NaN
# Del Taco                                 NaN
# Domino's                                 NaN
# Dunkin'                                  NaN
# El Pollo Loco                            NaN
# Firehouse Subs                           NaN
# Five Guys                                NaN
# Freddy’s Frozen Custard & Steakburgers   NaN
# Hardee’s                                 NaN
# In-N-Out Burger                          NaN
# ...
