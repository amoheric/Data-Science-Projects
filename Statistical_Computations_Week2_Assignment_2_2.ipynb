# %% [markdown]
# <a href="https://colab.research.google.com/github/amoheric/Data-Science-Projects/blob/main/Statistical_Computations_Week2_Assignment_2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
#importing more of python libraries like numpy, matplot, seaborn and scipy with pandas and sklearn.
import numpy as np

# %%
from sklearn.datasets import load_iris

import matplotlib.pyplot as plt

import seaborn as sns

from scipy import stats

# Load the Iris dataset
iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# %%
#Print the first 5 rows to observe your data
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# 1. Compute mean, median, and mode for each feature.

# %%
print("\nMean of each feature:")
print(iris_df.mean())

print("\nMedian of each feature:")
print(iris_df.median())

print("\nMode of each feature:")
print(iris_df.mode().iloc[0])
# Out:
# Mean of each feature:
# sepal length (cm)    5.843333
# sepal width (cm)     3.057333
# petal length (cm)    3.758000
# petal width (cm)     1.199333
# dtype: float64
#
# Median of each feature:
# sepal length (cm)    5.80
# sepal width (cm)     3.00
# petal length (cm)    4.35
# petal width (cm)     1.30
# dtype: float64
#
# Mode of each feature:
# sepal length (cm)    5.0
# sepal width (cm)     3.0
# petal length (cm)    1.4
# petal width (cm)     0.2
# Name: 0, dtype: float64

# %% [markdown]
# 2. Calculate the range, variance, and standard deviation for each feature.

# %%
print("\nRange of each feature:")
print(iris_df.max() - iris_df.min())

print("\nVariance of each feature:")
print(iris_df.var())

print("\nStandard deviation of each feature:")
print(iris_df.std())
# Out:
# Range of each feature:
# sepal length (cm)    3.6
# sepal width (cm)     2.4
# petal length (cm)    5.9
# petal width (cm)     2.4
# dtype: float64
#
# Variance of each feature:
# sepal length (cm)    0.685694
# sepal width (cm)     0.189979
# petal length (cm)    3.116278
# petal width (cm)     0.581006
# dtype: float64
#
# Standard deviation of each feature:
# sepal length (cm)    0.828066
# sepal width (cm)     0.435866
# petal length (cm)    1.765298
# petal width (cm)     0.762238
# dtype: float64

# %% [markdown]
# 3. Compute the 25th, 50th, and 75th percentiles (quartiles) for each feature.

# %%
print("\n25th percentile of each feature:")
print(iris_df.quantile(0.25))

print("\n50th percentile of each feature (Median):")
print(iris_df.quantile(0.5))

print("\n75th percentile of each feature:")
print(iris_df.quantile(0.75))
# Out:
# 25th percentile of each feature:
# sepal length (cm)    5.1
# sepal width (cm)     2.8
# petal length (cm)    1.6
# petal width (cm)     0.3
# Name: 0.25, dtype: float64
#
# 50th percentile of each feature (Median):
# sepal length (cm)    5.80
# sepal width (cm)     3.00
# petal length (cm)    4.35
# petal width (cm)     1.30
# Name: 0.5, dtype: float64
#
# 75th percentile of each feature:
# sepal length (cm)    6.4
# sepal width (cm)     3.3
# petal length (cm)    5.1
# petal width (cm)     1.8
# Name: 0.75, dtype: float64

# %% [markdown]
# 4. Create a histogram for each of the features to visualize their distributions.

# %%
iris_df.hist(bins=20, figsize=(10, 10))
plt.suptitle("Histograms of Iris Dataset Features")
plt.show()

# %% [markdown]
# 5. Plot scatter plots between pairs of features to explore relationships.

# %%
sns.pairplot(iris_df)
plt.suptitle("Scatter Plots between Pairs of Features")
plt.show()

# %% [markdown]
# # Resources: Help by co-pilot
